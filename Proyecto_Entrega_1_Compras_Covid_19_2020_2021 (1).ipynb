# %% [markdown]
# **Hipótesis**: *Las compras de productos no esenciales (como artículos de limpieza o papelería) aumentaron significativamente durante la pandemia en comparación con productos esenciales como medicamentos o insumos sanitarios.*

# %%
import pandas as pd

# %% [markdown]
# a)

# %%
#cargar el archivo 1 de covid
df =  pd.read_excel('compra-covid-2021-12-30.xlsx')

# %% [markdown]
# b)

# %%
df.head()
# Out:
#    id   numero_cotratacion                       expediente  \
# 0   1  2020-01-01 00:00:00  EX-2020-18513163- -APN-DCYC#MDS
# 1   2  2020-01-01 00:00:00  EX-2020-18513163- -APN-DCYC#MDS
# 2   3  2020-01-01 00:00:00  EX-2020-18513163- -APN-DCYC#MDS
# 3   4  2020-02-01 00:00:00  EX-2020-18515672- -APN-DCYC#MDS
# 4   5  2020-02-01 00:00:00  EX-2020-18515672- -APN-DCYC#MDS
#
#                         proceso_comprar  \
# 0  no habilitado al momento del llamado
# 1  no habilitado al momento del llamado
# 2  no habilitado al momento del llamado
# 3  no habilitado al momento del llamado
# 4  no habilitado al momento del llamado
#
#                                               objeto moneda  monto_adjudicado  \
# 0  1.700.000 Kg de leche entera en polvo  instant...  pesos       230520000.0
# 1  1.700.000 Kg de leche entera en polvo  instant...  pesos       230520000.0
# 2  1.700.000 Kg de leche entera en polvo  instant...  pesos       230520000.0
# ...

# %%
df.shape
# Out:
# (761, 23)

# %%
df.dtypes
# Out:
# id                                                                  int64
# numero_cotratacion                                                 object
# expediente                                                         object
# proceso_comprar                                                    object
# objeto                                                             object
# moneda                                                             object
# monto_adjudicado                                                  float64
# cantidad_de_invitados                                             float64
# oferente_razon_social                                              object
# oferente_cuit                                                     float64
# oferente_cantidad_ofrecido                                        float64
# oferente_monto_ofrecido                                           float64
# adjudicataria                                                      object
# ...

# %%
df.isnull().sum()
# Out:
# id                                                           0
# numero_cotratacion                                           0
# expediente                                                   0
# proceso_comprar                                              0
# objeto                                                       0
# moneda                                                      17
# monto_adjudicado                                            17
# cantidad_de_invitados                                       17
# oferente_razon_social                                       17
# oferente_cuit                                               17
# oferente_cantidad_ofrecido                                  17
# oferente_monto_ofrecido                                     17
# adjudicataria                                               17
# oferente_cantidad_adjudicado                               134
# oferente_cantidad_adjudicado_monto                         131
# ...

# %% [markdown]
# Para la hipotesis se va a analizar y filtrar las columnas *Objeto*, *Numero Contratacion* y *Monto adjudicado*.
